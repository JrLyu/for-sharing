# %% [markdown]
# # Univariate Linear Regression

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Importing relevant packages

# %%
import copy, math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining the data

# %%
x_train = np.array(np.random(1,10,100))
y_train = np.array(np.random(1,10,100))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_b/554mn6jx1vv8940qhs9gysv80000gn/T/ipykernel_91526/195460727.py in <module>
# ----> 1 x_train = np.array(np.random(1,10,100))
#       2 y_train = np.array(np.random(1,10,100))
#
# TypeError: 'module' object is not callable

# %%
print(f"X Shape: {x_train.shape}, X Type:{type(x_train)})")
print(x_train)
print(f"y Shape: {y_train.shape}, y Type:{type(y_train)})")
print(y_train)
# Out:
# X Shape: (100,), X Type:<class 'numpy.ndarray'>)
# [6.60927985 6.25585763 9.91175846 4.43425106 8.15372998 1.29672756
#  4.71208157 3.75436924 2.83020365 7.90181599 3.69442172 1.01352542
#  1.11011514 5.99553101 3.26351334 9.07283372 4.76595662 6.97102478
#  6.57598817 3.19874484 5.03718041 2.48243569 4.13833004 5.50685748
#  9.99811148 2.4693419  9.07395303 7.07074315 6.56269753 6.8606992
#  2.90843717 4.64981712 8.94595557 3.06186035 2.94376345 8.82361745
#  5.19551836 9.30311228 1.74108766 8.13101051 2.10521158 1.61026418
#  7.87502374 7.91276952 4.65400537 4.4583161  8.53108709 3.5220873
#  3.95281938 3.69031531 2.46880259 8.47454192 8.45729812 5.54654132
#  3.3538327  9.10188371 5.87161563 4.10454613 7.0367431  7.73921426
#  4.65744581 5.81187632 6.69342552 2.92713384 4.75108527 6.66378597
#  5.53123593 8.09483656 8.06102082 9.95878109 8.98281718 3.33935756
#  7.8514882  3.62237724 1.96552996 3.45852377 5.39416232 4.29587657
#  3.19854718 9.54134203 9.54453666 9.44522339 8.37398949 5.6525433
#  7.81016122 7.82775486 9.0048457  1.17557107 7.1510735  2.51070788
#  8.76320537 8.52190488 4.79255264 9.38926017 1.1402664  7.95408971
#  3.79396504 6.51281158 5.32844954 1.13569595]
# y Shape: (100,), y Type:<class 'numpy.ndarray'>)
# [4.46518556 2.78828815 3.26381241 1.65979078 9.48201762 9.38342488
#  5.0591506  7.98916332 8.33687647 8.67550563 8.95852447 6.13252341
#  7.65931902 5.24260349 2.95698229 1.79092033 9.96590644 5.37149552
#  5.06464044 5.09065882 5.63642558 9.08280394 1.71722079 2.26304641
#  1.2787414  9.3113288  3.69626505 9.19996662 1.40313622 1.97978979
#  3.13362268 6.78455292 7.29570298 9.9998251  9.84416012 6.84938896
#  8.63833833 6.22594958 2.58844461 9.14798492 7.21090662 7.70832199
#  6.09347247 8.32645258 3.65173475 7.65246666 3.10990543 2.78203523
#  8.85175292 5.13673262 2.06563954 1.56019413 9.73291133 3.1254068
#  3.62680247 9.95261443 7.81112458 4.48194896 4.67295793 8.63887432
#  9.63917011 9.13508067 6.55728855 7.37058881 7.95549005 5.66416441
#  8.47437535 1.67962732 7.47438352 9.99333474 9.48266128 2.11921588
#  8.88688139 1.50795658 8.563036   8.34861385 8.4845885  2.55363988
#  2.09261484 5.82147522 5.20252295 2.63069766 7.08271826 3.33112083
#  1.09546222 4.47726787 4.0149109  7.06225308 3.44814384 3.20403181
#  2.61124383 8.45955524 4.86914558 9.69671065 2.83916754 1.68462126
#  8.74582159 6.34166094 8.62852066 8.61493393]

# %% [markdown]
# ### Define the initial w and b

# %%
w_init = 1
b_init = 0

# %% [markdown]
# ### (Optional) Z-Score Normalization to make the machine learning process faster

# %%
def z_score_normal(x):
    mu = np.mean(x)
    sgm = np.std(x)
    x_z = (x - mu) / sgm
    return x_z

# %%
x_z = z_score_normal(x_train)
y_z = z_score_normal(y_train)
print(x_z)
print(y_z)
# Out:
# [ 0.36172032  0.22485479  1.64063109 -0.48057665  0.95982075 -1.69560726
#  -0.37298461 -0.74386622 -1.1017566   0.86226509 -0.76708137 -1.80527951
#  -1.76787438  0.12404126 -0.93395403  1.3157509  -0.35212107  0.50180888
#   0.34882786 -0.95903613 -0.24708753 -1.23643247 -0.59517439 -0.0652014
#   1.67407197 -1.24150315  1.31618435  0.54042561  0.34368095  0.45908444
#  -1.07146006 -0.397097    1.26661633 -1.01204573 -1.05777968  1.21923994
#  -0.18576991  1.40492808 -1.52352532  0.95102246 -1.38251547 -1.57418774
#   0.85188958  0.86650693 -0.39547507 -0.47125728  1.10595526 -0.83381923
#  -0.66701485 -0.76867161 -1.241712    1.0840577   1.0773799  -0.04983352
#  -0.89897714  1.32700073  0.07605406 -0.60825747  0.52725882  0.79929629
#  -0.39414273  0.05291954  0.39430639 -1.06421963 -0.35788012  0.38282824
#  -0.05576065  0.93701382  0.92391841  1.65884097  1.28089128 -0.90458275
#   0.84277525 -0.79498116 -1.43660828 -0.85843471 -0.10884348 -0.53416326
#  -0.95911268  1.49718442  1.49842156  1.45996172  1.04511798 -0.00878342
#   0.82677106  0.83358433  1.289422   -1.74252606  0.57153416 -1.22548385
#   1.19584488  1.10239938 -0.34182155  1.43828952 -1.75619807  0.88250849
#  -0.72853244  0.32436223 -0.13429127 -1.75796801]
# [-0.5000408  -1.09502123 -0.92630034 -1.4954237   1.27998277  1.24500105
#  -0.2892959   0.75030273  0.87367492  0.99382403  1.09424202  0.0915478
#   0.63327058 -0.22420493 -1.03516682 -1.44889759  1.4516715  -0.17847271
#  -0.28734805 -0.27811646 -0.0844728   1.13833765 -1.47504694 -1.2813824
#  -1.63062393  1.21942062 -0.7728617   1.17990818 -1.58648737 -1.38188476
#  -0.97249299  0.32289457  0.50425587  1.46370618  1.40847465  0.34589907
#   0.98063669  0.12469637 -1.16592778  1.16146453  0.47416925  0.65065733
#   0.07769213  0.86997642 -0.78866151  0.63083929 -0.98090812 -1.09723983
#   1.05635838 -0.261769   -1.35142439 -1.53076161  1.36900244 -0.97540807
#  -0.79750774  1.44695536  0.68713275 -0.49409297 -0.42632103  0.98082686
#   1.33574209  1.15688598  0.24225884  0.53082613  0.7383551  -0.07463078
#   0.92246094 -1.48838549  0.56765356  1.46140334  1.28021115 -1.33241495
#   1.06882232 -1.54929603  0.95391865  0.87783947  0.92608467 -1.17827685
#  -1.34185327 -0.01881529 -0.23842592 -1.15093596  0.4286867  -0.90241862
#  -1.69565327 -0.49575387 -0.65980288  0.42142544 -0.86089765 -0.94751111
#  -1.15783838  0.91720261 -0.35671163  1.35615807 -1.0769687  -1.48661359
#   1.01877286  0.16575195  0.97715328  0.97233257]

# %% [markdown]
# ### Plot the data onto a scatter plot

# %%
fig = plt.figure(1)
ax1=plt.subplot(2,1,1)
plt.scatter(x_train,y_train,marker='o')
plt.xlabel("x trained")
plt.ylabel("y trained")
plt.title('y train vs. x train')
ax2=plt.subplot(2,1,2)
plt.scatter(x_z,y_z,color="r",marker="*",linestyle="dashed")
plt.xlabel("x_z normalized")
plt.ylabel("y_z normalized")
plt.title('y normalized vs. x normalized')
plt.subplots_adjust(wspace=0,hspace=1)
plt.show()

# %% [markdown]
# ## Set up the model

# %%
def predict(x,w,b):
    p = w * x + b
    return p

# %%
f_wb = predict(x_train,w_init,b_init)
plt.scatter(x_train,y_train,marker='o')
plt.plot(x_train,f_wb,marker='o',markersize=0.1,color="r")
plt.xlabel("x trained")
plt.ylabel("y trained")
plt.title('y train vs. x train')
# Out:
# Text(0.5, 1.0, 'y train vs. x train')

# %% [markdown]
# ### Set up the cost function

# %%
def compute_cost(x,y,w,b):
    m = x.shape[0]
    cost = 0.0
    for i in range(m):
        f_wb_i = predict(x[i],w,b)
        cost = cost + (f_wb_i - y[i])**2
    cost = cost / (2*m)
    return cost

# %%
cost = compute_cost(x_train, y_train, w_init, b_init)
print(f'Cost at initial w : {cost}')
# Out:
# Cost at initial w : 7.807241721785239

# %% [markdown]
# ### Set up the Gradient Descent

# %%
def compute_gradient(x,y,w,b):
    m = x.shape[0]
    dj_dw = 0.0
    dj_db = 0.0
    for i in range(m):
        f_wb_i = predict(x[i],w,b)
        dj_dw = dj_dw + (f_wb_i - y[i]) * x[i]
        dj_db = dj_db + (f_wb_i - y[i])
    dj_dw = dj_dw / m
    dj_db = dj_db / m
    return dj_dw, dj_db

# %%
tmp_dj_dw, tmp_dj_db = compute_gradient(x_train, y_train, w_init, b_init)
print(f'dj_db at initial w,b: {tmp_dj_db}')
print(f'dj_dw at initial w,b: {tmp_dj_dw}')
# Out:
# dj_db at initial w,b: -0.19928001607904774
# dj_dw at initial w,b: 6.0187461137478735

# %%
def gradient_descent(x,y,w_int,b_int,cost_func,gradient_func,alpha,iteration): 
    w = copy.deepcopy(w_int)
    b = b_int
    J = cost_func(x,y,w_int,b_int)
    for i in range(iteration):
        dj_dw,dj_db = gradient_func(x,y,w,b)
        w = w - alpha * dj_dw
        b = b - alpha * dj_db
        J = cost_func(x,y,w,b)
        if i% math.ceil(iteration / 10) == 0:
            print(f"Iteration {i:4d}: Cost {J}")
    return w,b,J

# %% [markdown]
# ### Test the implement

# %%
initial_w = 1
initial_b = 0
alpha = 5e-3
iteration = 10000

w_final, b_final,J = gradient_descent(x_train, y_train, initial_w, initial_b,
                                                    compute_cost, compute_gradient, 
                                                    alpha, iteration)
print(f"b,w found by gradient descent: {b_final:0.2f},{w_final} ")
# Out:
# Iteration    0: Cost 7.643350749811575
# Iteration 1000: Cost 4.588937315954487
# Iteration 2000: Cost 4.072596811362772
# Iteration 3000: Cost 3.9763611342585845
# Iteration 4000: Cost 3.9584247038113434
# Iteration 5000: Cost 3.955081707254671
# Iteration 6000: Cost 3.9544586386897826
# Iteration 7000: Cost 3.954342511009133
# Iteration 8000: Cost 3.9543208671019077
# Iteration 9000: Cost 3.9543168331048673
# b,w found by gradient descent: 6.28,-0.07202359828754537

# %% [markdown]
# ### Draw the diagram

# %%
plt.scatter(x_train,y_train,color="b",marker='o')
plt.xlabel("x trained")
plt.ylabel("y trained")
plt.title('y train vs. x train')
f_final = predict(x_train,w_final,b_final)
plt.plot(x_train,f_final,color="r",marker="*",)

# %% [markdown]
# ## Do the prediction

# %%
x_value = 13
y_predict = predict(x_value,w_final,b_final)
print(f"Predicted value for x = {x_value} is {y_predict}")
plt.scatter(x_train,y_train,color="b",marker='*',s=100)
plt.xlabel("x trained")
plt.ylabel("y trained")
plt.title('y train vs. x train')
x = np.arange(0, 20, 0.1)
y = predict(x,w_final,b_final)
plt.plot(x,y,color="black",marker=".",linewidth=0.1,markersize=1)
plt.plot(x_value,y_predict,color="r",marker="o",markersize=10)
plt.annotate("This is the predict value", xy=(x_value,y_predict), xytext=(x_value, y_predict+1),
            arrowprops=dict(facecolor='black', shrink=0.01),
            )
# Out:
# Predicted value for x = 13 is 5.346709514935839
# Text(13, 6.346709514935839, 'This is the predict value')
